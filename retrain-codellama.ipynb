# %% [markdown]
# Setup development environment
#
# Our first step is to install Hugging Face Libraries and Pytorch, including trl, transformers and datasets. If you haven't heard of trl yet, don't worry. It is a new library on top of transformers and datasets, which makes it easier to fine-tune, rlhf, align open LLMs.

# %%
# Install Pytorch & other libraries
# %pip install "torch==2.1.2" tensorboard

# Install Hugging Face libraries
# %pip install  --upgrade \
  "transformers==4.36.2" \
  "datasets==2.16.1" \
  "accelerate==0.26.1" \
  "evaluate==0.4.1" \
  "bitsandbytes==0.42.0" \
  # "trl==0.7.10" # \
  # "peft==0.7.1" \

# install peft & trl from github
# %pip install git+https://github.com/huggingface/trl@a3c5b7178ac4f65569975efadc97db2f3749c65e --upgrade
# %pip install git+https://github.com/huggingface/peft@4a1559582281fc3c9283892caea8ccef1d6f5a4f --upgrade
# Out:
# Requirement already satisfied: torch==2.1.2 in ./.venv/lib/python3.10/site-packages (2.1.2)
# Requirement already satisfied: tensorboard in ./.venv/lib/python3.10/site-packages (2.16.2)
# Requirement already satisfied: sympy in ./.venv/lib/python3.10/site-packages (from torch==2.1.2) (1.12)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in ./.venv/lib/python3.10/site-packages (from torch==2.1.2) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in ./.venv/lib/python3.10/site-packages (from torch==2.1.2) (12.1.105)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in ./.venv/lib/python3.10/site-packages (from torch==2.1.2) (12.1.0.106)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in ./.venv/lib/python3.10/site-packages (from torch==2.1.2) (12.1.105)
# Requirement already satisfied: jinja2 in ./.venv/lib/python3.10/site-packages (from torch==2.1.2) (3.1.3)
# Requirement already satisfied: fsspec in ./.venv/lib/python3.10/site-packages (from torch==2.1.2) (2023.10.0)
# Requirement already satisfied: typing-extensions in ./.venv/lib/python3.10/site-packages (from torch==2.1.2) (4.10.0)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in ./.venv/lib/python3.10/site-packages (from torch==2.1.2) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in ./.venv/lib/python3.10/site-packages (from torch==2.1.2) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in ./.venv/lib/python3.10/site-packages (from torch==2.1.2) (11.0.2.54)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in ./.venv/lib/python3.10/site-packages (from torch==2.1.2) (12.1.105)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in ./.venv/lib/python3.10/site-packages (from torch==2.1.2) (10.3.2.106)
# Requirement already satisfied: networkx in ./.venv/lib/python3.10/site-packages (from torch==2.1.2) (3.2.1)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in ./.venv/lib/python3.10/site-packages (from torch==2.1.2) (11.4.5.107)
# Requirement already satisfied: filelock in ./.venv/lib/python3.10/site-packages (from torch==2.1.2) (3.13.1)
# Requirement already satisfied: triton==2.1.0 in ./.venv/lib/python3.10/site-packages (from torch==2.1.2) (2.1.0)
# Requirement already satisfied: nvidia-nccl-cu12==2.18.1 in ./.venv/lib/python3.10/site-packages (from torch==2.1.2) (2.18.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in ./.venv/lib/python3.10/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch==2.1.2) (12.3.101)
# Requirement already satisfied: absl-py>=0.4 in ./.venv/lib/python3.10/site-packages (from tensorboard) (2.1.0)
# Requirement already satisfied: grpcio>=1.48.2 in ./.venv/lib/python3.10/site-packages (from tensorboard) (1.62.0)
# Requirement already satisfied: numpy>=1.12.0 in ./.venv/lib/python3.10/site-packages (from tensorboard) (1.26.4)
# Requirement already satisfied: six>1.9 in ./.venv/lib/python3.10/site-packages (from tensorboard) (1.16.0)
# Requirement already satisfied: setuptools>=41.0.0 in ./.venv/lib/python3.10/site-packages (from tensorboard) (59.6.0)
# Requirement already satisfied: werkzeug>=1.0.1 in ./.venv/lib/python3.10/site-packages (from tensorboard) (3.0.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in ./.venv/lib/python3.10/site-packages (from tensorboard) (0.7.2)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in ./.venv/lib/python3.10/site-packages (from tensorboard) (4.25.3)
# Requirement already satisfied: markdown>=2.6.8 in ./.venv/lib/python3.10/site-packages (from tensorboard) (3.5.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in ./.venv/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in ./.venv/lib/python3.10/site-packages (from sympy->torch==2.1.2) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: transformers==4.36.2 in ./.venv/lib/python3.10/site-packages (4.36.2)
# Requirement already satisfied: datasets==2.16.1 in ./.venv/lib/python3.10/site-packages (2.16.1)
# Requirement already satisfied: accelerate==0.26.1 in ./.venv/lib/python3.10/site-packages (0.26.1)
# Requirement already satisfied: evaluate==0.4.1 in ./.venv/lib/python3.10/site-packages (0.4.1)
# Requirement already satisfied: bitsandbytes==0.42.0 in ./.venv/lib/python3.10/site-packages (0.42.0)
# Requirement already satisfied: regex!=2019.12.17 in ./.venv/lib/python3.10/site-packages (from transformers==4.36.2) (2023.12.25)
# Requirement already satisfied: safetensors>=0.3.1 in ./.venv/lib/python3.10/site-packages (from transformers==4.36.2) (0.4.2)
# Requirement already satisfied: packaging>=20.0 in ./.venv/lib/python3.10/site-packages (from transformers==4.36.2) (23.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in ./.venv/lib/python3.10/site-packages (from transformers==4.36.2) (0.21.3)
# Requirement already satisfied: numpy>=1.17 in ./.venv/lib/python3.10/site-packages (from transformers==4.36.2) (1.26.4)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in ./.venv/lib/python3.10/site-packages (from transformers==4.36.2) (0.15.2)
# Requirement already satisfied: requests in ./.venv/lib/python3.10/site-packages (from transformers==4.36.2) (2.31.0)
# Requirement already satisfied: filelock in ./.venv/lib/python3.10/site-packages (from transformers==4.36.2) (3.13.1)
# Requirement already satisfied: tqdm>=4.27 in ./.venv/lib/python3.10/site-packages (from transformers==4.36.2) (4.66.2)
# Requirement already satisfied: pyyaml>=5.1 in ./.venv/lib/python3.10/site-packages (from transformers==4.36.2) (6.0.1)
# Requirement already satisfied: pandas in ./.venv/lib/python3.10/site-packages (from datasets==2.16.1) (2.2.1)
# Requirement already satisfied: multiprocess in ./.venv/lib/python3.10/site-packages (from datasets==2.16.1) (0.70.15)
# Requirement already satisfied: dill<0.3.8,>=0.3.0 in ./.venv/lib/python3.10/site-packages (from datasets==2.16.1) (0.3.7)
# Requirement already satisfied: fsspec[http]<=2023.10.0,>=2023.1.0 in ./.venv/lib/python3.10/site-packages (from datasets==2.16.1) (2023.10.0)
# Requirement already satisfied: pyarrow-hotfix in ./.venv/lib/python3.10/site-packages (from datasets==2.16.1) (0.6)
# Requirement already satisfied: aiohttp in ./.venv/lib/python3.10/site-packages (from datasets==2.16.1) (3.9.3)
# Requirement already satisfied: pyarrow>=8.0.0 in ./.venv/lib/python3.10/site-packages (from datasets==2.16.1) (15.0.0)
# Requirement already satisfied: xxhash in ./.venv/lib/python3.10/site-packages (from datasets==2.16.1) (3.4.1)
# Requirement already satisfied: psutil in ./.venv/lib/python3.10/site-packages (from accelerate==0.26.1) (5.9.8)
# Requirement already satisfied: torch>=1.10.0 in ./.venv/lib/python3.10/site-packages (from accelerate==0.26.1) (2.1.2)
# Requirement already satisfied: responses<0.19 in ./.venv/lib/python3.10/site-packages (from evaluate==0.4.1) (0.18.0)
# Requirement already satisfied: scipy in ./.venv/lib/python3.10/site-packages (from bitsandbytes==0.42.0) (1.12.0)
# Requirement already satisfied: aiosignal>=1.1.2 in ./.venv/lib/python3.10/site-packages (from aiohttp->datasets==2.16.1) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in ./.venv/lib/python3.10/site-packages (from aiohttp->datasets==2.16.1) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in ./.venv/lib/python3.10/site-packages (from aiohttp->datasets==2.16.1) (1.9.4)
# Requirement already satisfied: attrs>=17.3.0 in ./.venv/lib/python3.10/site-packages (from aiohttp->datasets==2.16.1) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in ./.venv/lib/python3.10/site-packages (from aiohttp->datasets==2.16.1) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./.venv/lib/python3.10/site-packages (from aiohttp->datasets==2.16.1) (6.0.5)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in ./.venv/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.19.3->transformers==4.36.2) (4.10.0)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv/lib/python3.10/site-packages (from requests->transformers==4.36.2) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.10/site-packages (from requests->transformers==4.36.2) (2.2.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.venv/lib/python3.10/site-packages (from requests->transformers==4.36.2) (3.3.2)
# Requirement already satisfied: certifi>=2017.4.17 in ./.venv/lib/python3.10/site-packages (from requests->transformers==4.36.2) (2024.2.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in ./.venv/lib/python3.10/site-packages (from torch>=1.10.0->accelerate==0.26.1) (12.1.0.106)
# Requirement already satisfied: jinja2 in ./.venv/lib/python3.10/site-packages (from torch>=1.10.0->accelerate==0.26.1) (3.1.3)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in ./.venv/lib/python3.10/site-packages (from torch>=1.10.0->accelerate==0.26.1) (12.1.105)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in ./.venv/lib/python3.10/site-packages (from torch>=1.10.0->accelerate==0.26.1) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in ./.venv/lib/python3.10/site-packages (from torch>=1.10.0->accelerate==0.26.1) (12.1.105)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in ./.venv/lib/python3.10/site-packages (from torch>=1.10.0->accelerate==0.26.1) (10.3.2.106)
# Requirement already satisfied: networkx in ./.venv/lib/python3.10/site-packages (from torch>=1.10.0->accelerate==0.26.1) (3.2.1)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in ./.venv/lib/python3.10/site-packages (from torch>=1.10.0->accelerate==0.26.1) (12.1.3.1)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in ./.venv/lib/python3.10/site-packages (from torch>=1.10.0->accelerate==0.26.1) (11.4.5.107)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in ./.venv/lib/python3.10/site-packages (from torch>=1.10.0->accelerate==0.26.1) (11.0.2.54)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in ./.venv/lib/python3.10/site-packages (from torch>=1.10.0->accelerate==0.26.1) (12.1.105)
# Requirement already satisfied: triton==2.1.0 in ./.venv/lib/python3.10/site-packages (from torch>=1.10.0->accelerate==0.26.1) (2.1.0)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in ./.venv/lib/python3.10/site-packages (from torch>=1.10.0->accelerate==0.26.1) (8.9.2.26)
# Requirement already satisfied: nvidia-nccl-cu12==2.18.1 in ./.venv/lib/python3.10/site-packages (from torch>=1.10.0->accelerate==0.26.1) (2.18.1)
# Requirement already satisfied: sympy in ./.venv/lib/python3.10/site-packages (from torch>=1.10.0->accelerate==0.26.1) (1.12)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in ./.venv/lib/python3.10/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.10.0->accelerate==0.26.1) (12.3.101)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.10/site-packages (from pandas->datasets==2.16.1) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in ./.venv/lib/python3.10/site-packages (from pandas->datasets==2.16.1) (2024.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.venv/lib/python3.10/site-packages (from pandas->datasets==2.16.1) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->datasets==2.16.1) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.venv/lib/python3.10/site-packages (from jinja2->torch>=1.10.0->accelerate==0.26.1) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in ./.venv/lib/python3.10/site-packages (from sympy->torch>=1.10.0->accelerate==0.26.1) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.
# Collecting git+https://github.com/huggingface/trl@a3c5b7178ac4f65569975efadc97db2f3749c65e
#   Cloning https://github.com/huggingface/trl (to revision a3c5b7178ac4f65569975efadc97db2f3749c65e) to /tmp/pip-req-build-3rsg_a8_
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/trl /tmp/pip-req-build-3rsg_a8_
#   Running command git rev-parse -q --verify 'sha^a3c5b7178ac4f65569975efadc97db2f3749c65e'
#   Running command git fetch -q https://github.com/huggingface/trl a3c5b7178ac4f65569975efadc97db2f3749c65e
#   Running command git checkout -q a3c5b7178ac4f65569975efadc97db2f3749c65e
#   Resolved https://github.com/huggingface/trl to commit a3c5b7178ac4f65569975efadc97db2f3749c65e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: accelerate in ./.venv/lib/python3.10/site-packages (from trl==0.7.11.dev0) (0.26.1)
# Requirement already satisfied: numpy>=1.18.2 in ./.venv/lib/python3.10/site-packages (from trl==0.7.11.dev0) (1.26.4)
# Requirement already satisfied: tyro>=0.5.11 in ./.venv/lib/python3.10/site-packages (from trl==0.7.11.dev0) (0.7.3)
# Requirement already satisfied: datasets in ./.venv/lib/python3.10/site-packages (from trl==0.7.11.dev0) (2.16.1)
# Requirement already satisfied: transformers>=4.31.0 in ./.venv/lib/python3.10/site-packages (from trl==0.7.11.dev0) (4.36.2)
# Requirement already satisfied: torch>=1.4.0 in ./.venv/lib/python3.10/site-packages (from trl==0.7.11.dev0) (2.1.2)
# Requirement already satisfied: filelock in ./.venv/lib/python3.10/site-packages (from torch>=1.4.0->trl==0.7.11.dev0) (3.13.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in ./.venv/lib/python3.10/site-packages (from torch>=1.4.0->trl==0.7.11.dev0) (12.1.105)
# Requirement already satisfied: nvidia-nccl-cu12==2.18.1 in ./.venv/lib/python3.10/site-packages (from torch>=1.4.0->trl==0.7.11.dev0) (2.18.1)
# Requirement already satisfied: fsspec in ./.venv/lib/python3.10/site-packages (from torch>=1.4.0->trl==0.7.11.dev0) (2023.10.0)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in ./.venv/lib/python3.10/site-packages (from torch>=1.4.0->trl==0.7.11.dev0) (11.4.5.107)
# Requirement already satisfied: jinja2 in ./.venv/lib/python3.10/site-packages (from torch>=1.4.0->trl==0.7.11.dev0) (3.1.3)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in ./.venv/lib/python3.10/site-packages (from torch>=1.4.0->trl==0.7.11.dev0) (12.1.105)
# Requirement already satisfied: typing-extensions in ./.venv/lib/python3.10/site-packages (from torch>=1.4.0->trl==0.7.11.dev0) (4.10.0)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in ./.venv/lib/python3.10/site-packages (from torch>=1.4.0->trl==0.7.11.dev0) (8.9.2.26)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in ./.venv/lib/python3.10/site-packages (from torch>=1.4.0->trl==0.7.11.dev0) (12.1.105)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in ./.venv/lib/python3.10/site-packages (from torch>=1.4.0->trl==0.7.11.dev0) (12.1.0.106)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in ./.venv/lib/python3.10/site-packages (from torch>=1.4.0->trl==0.7.11.dev0) (11.0.2.54)
# Requirement already satisfied: triton==2.1.0 in ./.venv/lib/python3.10/site-packages (from torch>=1.4.0->trl==0.7.11.dev0) (2.1.0)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in ./.venv/lib/python3.10/site-packages (from torch>=1.4.0->trl==0.7.11.dev0) (12.1.105)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in ./.venv/lib/python3.10/site-packages (from torch>=1.4.0->trl==0.7.11.dev0) (10.3.2.106)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in ./.venv/lib/python3.10/site-packages (from torch>=1.4.0->trl==0.7.11.dev0) (12.1.3.1)
# Requirement already satisfied: networkx in ./.venv/lib/python3.10/site-packages (from torch>=1.4.0->trl==0.7.11.dev0) (3.2.1)
# Requirement already satisfied: sympy in ./.venv/lib/python3.10/site-packages (from torch>=1.4.0->trl==0.7.11.dev0) (1.12)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in ./.venv/lib/python3.10/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.4.0->trl==0.7.11.dev0) (12.3.101)
# Requirement already satisfied: pyyaml>=5.1 in ./.venv/lib/python3.10/site-packages (from transformers>=4.31.0->trl==0.7.11.dev0) (6.0.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in ./.venv/lib/python3.10/site-packages (from transformers>=4.31.0->trl==0.7.11.dev0) (0.21.3)
# Requirement already satisfied: requests in ./.venv/lib/python3.10/site-packages (from transformers>=4.31.0->trl==0.7.11.dev0) (2.31.0)
# Requirement already satisfied: regex!=2019.12.17 in ./.venv/lib/python3.10/site-packages (from transformers>=4.31.0->trl==0.7.11.dev0) (2023.12.25)
# Requirement already satisfied: tqdm>=4.27 in ./.venv/lib/python3.10/site-packages (from transformers>=4.31.0->trl==0.7.11.dev0) (4.66.2)
# Requirement already satisfied: packaging>=20.0 in ./.venv/lib/python3.10/site-packages (from transformers>=4.31.0->trl==0.7.11.dev0) (23.2)
# Requirement already satisfied: safetensors>=0.3.1 in ./.venv/lib/python3.10/site-packages (from transformers>=4.31.0->trl==0.7.11.dev0) (0.4.2)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in ./.venv/lib/python3.10/site-packages (from transformers>=4.31.0->trl==0.7.11.dev0) (0.15.2)
# Requirement already satisfied: shtab>=1.5.6 in ./.venv/lib/python3.10/site-packages (from tyro>=0.5.11->trl==0.7.11.dev0) (1.7.0)
# Requirement already satisfied: docstring-parser>=0.14.1 in ./.venv/lib/python3.10/site-packages (from tyro>=0.5.11->trl==0.7.11.dev0) (0.15)
# Requirement already satisfied: rich>=11.1.0 in ./.venv/lib/python3.10/site-packages (from tyro>=0.5.11->trl==0.7.11.dev0) (13.7.1)
# Requirement already satisfied: psutil in ./.venv/lib/python3.10/site-packages (from accelerate->trl==0.7.11.dev0) (5.9.8)
# Requirement already satisfied: dill<0.3.8,>=0.3.0 in ./.venv/lib/python3.10/site-packages (from datasets->trl==0.7.11.dev0) (0.3.7)
# Requirement already satisfied: pandas in ./.venv/lib/python3.10/site-packages (from datasets->trl==0.7.11.dev0) (2.2.1)
# Requirement already satisfied: multiprocess in ./.venv/lib/python3.10/site-packages (from datasets->trl==0.7.11.dev0) (0.70.15)
# Requirement already satisfied: xxhash in ./.venv/lib/python3.10/site-packages (from datasets->trl==0.7.11.dev0) (3.4.1)
# Requirement already satisfied: pyarrow-hotfix in ./.venv/lib/python3.10/site-packages (from datasets->trl==0.7.11.dev0) (0.6)
# Requirement already satisfied: pyarrow>=8.0.0 in ./.venv/lib/python3.10/site-packages (from datasets->trl==0.7.11.dev0) (15.0.0)
# Requirement already satisfied: aiohttp in ./.venv/lib/python3.10/site-packages (from datasets->trl==0.7.11.dev0) (3.9.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in ./.venv/lib/python3.10/site-packages (from aiohttp->datasets->trl==0.7.11.dev0) (1.9.4)
# Requirement already satisfied: attrs>=17.3.0 in ./.venv/lib/python3.10/site-packages (from aiohttp->datasets->trl==0.7.11.dev0) (23.2.0)
# Requirement already satisfied: aiosignal>=1.1.2 in ./.venv/lib/python3.10/site-packages (from aiohttp->datasets->trl==0.7.11.dev0) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in ./.venv/lib/python3.10/site-packages (from aiohttp->datasets->trl==0.7.11.dev0) (4.0.3)
# Requirement already satisfied: frozenlist>=1.1.1 in ./.venv/lib/python3.10/site-packages (from aiohttp->datasets->trl==0.7.11.dev0) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./.venv/lib/python3.10/site-packages (from aiohttp->datasets->trl==0.7.11.dev0) (6.0.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.venv/lib/python3.10/site-packages (from requests->transformers>=4.31.0->trl==0.7.11.dev0) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.10/site-packages (from requests->transformers>=4.31.0->trl==0.7.11.dev0) (2.2.1)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv/lib/python3.10/site-packages (from requests->transformers>=4.31.0->trl==0.7.11.dev0) (3.6)
# Requirement already satisfied: certifi>=2017.4.17 in ./.venv/lib/python3.10/site-packages (from requests->transformers>=4.31.0->trl==0.7.11.dev0) (2024.2.2)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in ./.venv/lib/python3.10/site-packages (from rich>=11.1.0->tyro>=0.5.11->trl==0.7.11.dev0) (2.17.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in ./.venv/lib/python3.10/site-packages (from rich>=11.1.0->tyro>=0.5.11->trl==0.7.11.dev0) (3.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.venv/lib/python3.10/site-packages (from jinja2->torch>=1.4.0->trl==0.7.11.dev0) (2.1.5)
# Requirement already satisfied: tzdata>=2022.7 in ./.venv/lib/python3.10/site-packages (from pandas->datasets->trl==0.7.11.dev0) (2024.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.venv/lib/python3.10/site-packages (from pandas->datasets->trl==0.7.11.dev0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.10/site-packages (from pandas->datasets->trl==0.7.11.dev0) (2024.1)
# Requirement already satisfied: mpmath>=0.19 in ./.venv/lib/python3.10/site-packages (from sympy->torch>=1.4.0->trl==0.7.11.dev0) (1.3.0)
# Requirement already satisfied: mdurl~=0.1 in ./.venv/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=11.1.0->tyro>=0.5.11->trl==0.7.11.dev0) (0.1.2)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->datasets->trl==0.7.11.dev0) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Collecting git+https://github.com/huggingface/peft@4a1559582281fc3c9283892caea8ccef1d6f5a4f
#   Cloning https://github.com/huggingface/peft (to revision 4a1559582281fc3c9283892caea8ccef1d6f5a4f) to /tmp/pip-req-build-3_im0rnv
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/peft /tmp/pip-req-build-3_im0rnv
#   Running command git rev-parse -q --verify 'sha^4a1559582281fc3c9283892caea8ccef1d6f5a4f'
#   Running command git fetch -q https://github.com/huggingface/peft 4a1559582281fc3c9283892caea8ccef1d6f5a4f
#   Running command git checkout -q 4a1559582281fc3c9283892caea8ccef1d6f5a4f
#   Resolved https://github.com/huggingface/peft to commit 4a1559582281fc3c9283892caea8ccef1d6f5a4f
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: pyyaml in ./.venv/lib/python3.10/site-packages (from peft==0.7.2.dev0) (6.0.1)
# Requirement already satisfied: transformers in ./.venv/lib/python3.10/site-packages (from peft==0.7.2.dev0) (4.36.2)
# Requirement already satisfied: safetensors in ./.venv/lib/python3.10/site-packages (from peft==0.7.2.dev0) (0.4.2)
# Requirement already satisfied: tqdm in ./.venv/lib/python3.10/site-packages (from peft==0.7.2.dev0) (4.66.2)
# Requirement already satisfied: torch>=1.13.0 in ./.venv/lib/python3.10/site-packages (from peft==0.7.2.dev0) (2.1.2)
# Requirement already satisfied: packaging>=20.0 in ./.venv/lib/python3.10/site-packages (from peft==0.7.2.dev0) (23.2)
# Requirement already satisfied: numpy>=1.17 in ./.venv/lib/python3.10/site-packages (from peft==0.7.2.dev0) (1.26.4)
# Requirement already satisfied: accelerate>=0.21.0 in ./.venv/lib/python3.10/site-packages (from peft==0.7.2.dev0) (0.26.1)
# Requirement already satisfied: psutil in ./.venv/lib/python3.10/site-packages (from peft==0.7.2.dev0) (5.9.8)
# Requirement already satisfied: huggingface-hub>=0.17.0 in ./.venv/lib/python3.10/site-packages (from peft==0.7.2.dev0) (0.21.3)
# Requirement already satisfied: fsspec>=2023.5.0 in ./.venv/lib/python3.10/site-packages (from huggingface-hub>=0.17.0->peft==0.7.2.dev0) (2023.10.0)
# Requirement already satisfied: filelock in ./.venv/lib/python3.10/site-packages (from huggingface-hub>=0.17.0->peft==0.7.2.dev0) (3.13.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in ./.venv/lib/python3.10/site-packages (from huggingface-hub>=0.17.0->peft==0.7.2.dev0) (4.10.0)
# Requirement already satisfied: requests in ./.venv/lib/python3.10/site-packages (from huggingface-hub>=0.17.0->peft==0.7.2.dev0) (2.31.0)
# Requirement already satisfied: networkx in ./.venv/lib/python3.10/site-packages (from torch>=1.13.0->peft==0.7.2.dev0) (3.2.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in ./.venv/lib/python3.10/site-packages (from torch>=1.13.0->peft==0.7.2.dev0) (12.1.105)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in ./.venv/lib/python3.10/site-packages (from torch>=1.13.0->peft==0.7.2.dev0) (12.1.3.1)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in ./.venv/lib/python3.10/site-packages (from torch>=1.13.0->peft==0.7.2.dev0) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in ./.venv/lib/python3.10/site-packages (from torch>=1.13.0->peft==0.7.2.dev0) (12.1.105)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in ./.venv/lib/python3.10/site-packages (from torch>=1.13.0->peft==0.7.2.dev0) (11.0.2.54)
# Requirement already satisfied: jinja2 in ./.venv/lib/python3.10/site-packages (from torch>=1.13.0->peft==0.7.2.dev0) (3.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in ./.venv/lib/python3.10/site-packages (from torch>=1.13.0->peft==0.7.2.dev0) (10.3.2.106)
# Requirement already satisfied: triton==2.1.0 in ./.venv/lib/python3.10/site-packages (from torch>=1.13.0->peft==0.7.2.dev0) (2.1.0)
# Requirement already satisfied: nvidia-nccl-cu12==2.18.1 in ./.venv/lib/python3.10/site-packages (from torch>=1.13.0->peft==0.7.2.dev0) (2.18.1)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in ./.venv/lib/python3.10/site-packages (from torch>=1.13.0->peft==0.7.2.dev0) (12.1.0.106)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in ./.venv/lib/python3.10/site-packages (from torch>=1.13.0->peft==0.7.2.dev0) (12.1.105)
# Requirement already satisfied: sympy in ./.venv/lib/python3.10/site-packages (from torch>=1.13.0->peft==0.7.2.dev0) (1.12)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in ./.venv/lib/python3.10/site-packages (from torch>=1.13.0->peft==0.7.2.dev0) (11.4.5.107)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in ./.venv/lib/python3.10/site-packages (from torch>=1.13.0->peft==0.7.2.dev0) (8.9.2.26)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in ./.venv/lib/python3.10/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.13.0->peft==0.7.2.dev0) (12.3.101)
# Requirement already satisfied: regex!=2019.12.17 in ./.venv/lib/python3.10/site-packages (from transformers->peft==0.7.2.dev0) (2023.12.25)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in ./.venv/lib/python3.10/site-packages (from transformers->peft==0.7.2.dev0) (0.15.2)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.venv/lib/python3.10/site-packages (from jinja2->torch>=1.13.0->peft==0.7.2.dev0) (2.1.5)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.10/site-packages (from requests->huggingface-hub>=0.17.0->peft==0.7.2.dev0) (2.2.1)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv/lib/python3.10/site-packages (from requests->huggingface-hub>=0.17.0->peft==0.7.2.dev0) (3.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.venv/lib/python3.10/site-packages (from requests->huggingface-hub>=0.17.0->peft==0.7.2.dev0) (3.3.2)
# Requirement already satisfied: certifi>=2017.4.17 in ./.venv/lib/python3.10/site-packages (from requests->huggingface-hub>=0.17.0->peft==0.7.2.dev0) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in ./.venv/lib/python3.10/site-packages (from sympy->torch>=1.13.0->peft==0.7.2.dev0) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch; assert torch.cuda.get_device_capability()[0] >= 8, 'Hardware not supported for Flash Attention'
# install flash-attn
# %pip install wheel
# %pip install ninja packaging
# !MAX_JOBS=4 pip install flash-attn --no-build-isolation

# %env PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True
# Out:
# Requirement already satisfied: wheel in ./.venv/lib/python3.10/site-packages (0.42.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: ninja in ./.venv/lib/python3.10/site-packages (1.11.1.1)
# Requirement already satisfied: packaging in ./.venv/lib/python3.10/site-packages (23.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: flash-attn in ./.venv/lib/python3.10/site-packages (2.5.6)
# Requirement already satisfied: einops in ./.venv/lib/python3.10/site-packages (from flash-attn) (0.7.0)
# Requirement already satisfied: torch in ./.venv/lib/python3.10/site-packages (from flash-attn) (2.1.2)
# Requirement already satisfied: ninja in ./.venv/lib/python3.10/site-packages (from flash-attn) (1.11.1.1)
# Requirement already satisfied: packaging in ./.venv/lib/python3.10/site-packages (from flash-attn) (23.2)
# Requirement already satisfied: jinja2 in ./.venv/lib/python3.10/site-packages (from torch->flash-attn) (3.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in ./.venv/lib/python3.10/site-packages (from torch->flash-attn) (10.3.2.106)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in ./.venv/lib/python3.10/site-packages (from torch->flash-attn) (12.1.105)
# Requirement already satisfied: sympy in ./.venv/lib/python3.10/site-packages (from torch->flash-attn) (1.12)
# Requirement already satisfied: triton==2.1.0 in ./.venv/lib/python3.10/site-packages (from torch->flash-attn) (2.1.0)
# Requirement already satisfied: networkx in ./.venv/lib/python3.10/site-packages (from torch->flash-attn) (3.2.1)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in ./.venv/lib/python3.10/site-packages (from torch->flash-attn) (12.1.3.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in ./.venv/lib/python3.10/site-packages (from torch->flash-attn) (12.1.105)
# Requirement already satisfied: fsspec in ./.venv/lib/python3.10/site-packages (from torch->flash-attn) (2023.10.0)
# Requirement already satisfied: filelock in ./.venv/lib/python3.10/site-packages (from torch->flash-attn) (3.13.1)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in ./.venv/lib/python3.10/site-packages (from torch->flash-attn) (8.9.2.26)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in ./.venv/lib/python3.10/site-packages (from torch->flash-attn) (11.0.2.54)
# Requirement already satisfied: nvidia-nccl-cu12==2.18.1 in ./.venv/lib/python3.10/site-packages (from torch->flash-attn) (2.18.1)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in ./.venv/lib/python3.10/site-packages (from torch->flash-attn) (12.1.105)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in ./.venv/lib/python3.10/site-packages (from torch->flash-attn) (12.1.0.106)
# Requirement already satisfied: typing-extensions in ./.venv/lib/python3.10/site-packages (from torch->flash-attn) (4.10.0)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in ./.venv/lib/python3.10/site-packages (from torch->flash-attn) (12.1.105)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in ./.venv/lib/python3.10/site-packages (from torch->flash-attn) (11.4.5.107)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in ./.venv/lib/python3.10/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch->flash-attn) (12.3.101)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.venv/lib/python3.10/site-packages (from jinja2->torch->flash-attn) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in ./.venv/lib/python3.10/site-packages (from sympy->torch->flash-attn) (1.3.0)
# env: PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True

# %% [markdown]
# Create and prepare the dataset

# %%
from datasets import load_dataset

# Convert dataset to OAI messages
system_message = """You are an text to SQL query translator. Users will ask you questions in English and you will generate a SQL query based on the provided SCHEMA.
SCHEMA:
{schema}"""

def create_conversation(sample):
  return {
    "messages": [
      {"role": "system", "content": system_message.format(schema=sample["context"])},
      {"role": "user", "content": sample["question"]},
      {"role": "assistant", "content": sample["answer"]}
    ]
  }

# Load dataset from the hub
dataset = load_dataset("b-mc2/sql-create-context", split="train")
dataset = dataset.shuffle().select(range(12500)) #12500

# Convert dataset to OAI messages
dataset = dataset.map(create_conversation, remove_columns=dataset.features,batched=False)

dataset = dataset.train_test_split(test_size=100/12500)

# print(dataset["train"][0]["messages"]) #345

# save datasets to disk
dataset["train"].select(range(100)).to_json("retrain/train_dataset.json", orient="records")
dataset["test"].to_json("retrain/test_dataset.json", orient="records")
# Out:
# Map: 100%|██████████| 12500/12500 [00:01<00:00, 7021.89 examples/s]
# Creating json from Arrow format: 100%|██████████| 1/1 [00:00<00:00, 275.34ba/s]
# Creating json from Arrow format: 100%|██████████| 1/1 [00:00<00:00, 351.46ba/s]
# 48217

# %% [markdown]
# Fine-tune LLM using trl and the SFTTrainer

# %%
from datasets import load_dataset

# Load jsonl data from disk
dataset = load_dataset("json", data_files="retrain/train_dataset.json", split="train")

# print(dataset)

import torch
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig
from trl import setup_chat_format

# Hugging Face model id
model_id = "codellama/CodeLlama-7b-Instruct-hf" # "codellama/CodeLlama-7b-hf" # or `mistralai/Mistral-7B-v0.1`

# BitsAndBytesConfig int-4 config
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True, bnb_4bit_use_double_quant=True, bnb_4bit_quant_type="nf4", bnb_4bit_compute_dtype=torch.bfloat16
)

# bnb_config = BitsAndBytesConfig(
#    load_in_4bit=True,
#    bnb_4bit_compute_dtype=torch.bfloat16
# )

# Load model and tokenizer
model = AutoModelForCausalLM.from_pretrained(
    model_id,
    device_map="auto",
    attn_implementation="flash_attention_2",
    torch_dtype=torch.bfloat16,
    quantization_config=bnb_config
)
tokenizer = AutoTokenizer.from_pretrained(model_id)
tokenizer.padding_side = 'right' # to prevent warnings

# # set chat template to OAI chatML, remove if you start from a fine-tuned model
model, tokenizer = setup_chat_format(model, tokenizer)



from peft import LoraConfig

# LoRA config based on QLoRA paper & Sebastian Raschka experiment
peft_config = LoraConfig(
        lora_alpha=128,
        lora_dropout=0.05,
        r=256,
        bias="none",
        target_modules="all-linear",
        task_type="CAUSAL_LM",
)
# peft_config = LoraConfig(
#     r=16,  # dimension of the updated matrices
#     lora_alpha=64,  # parameter for scaling
#     target_modules=[
#     "q_proj",
#     "up_proj",
#     "o_proj",
#     "k_proj",
#     "down_proj",
#     "gate_proj",
#     "v_proj"],
#     lora_dropout=0.1,  # dropout probability for layers
#     bias="none",
#     task_type="CAUSAL_LM",
# )



from transformers import TrainingArguments

args = TrainingArguments(
    output_dir="./models/codeLlama-7b-text-to-sql", # directory to save and repository id
    num_train_epochs=3,                     # number of training epochs
    per_device_train_batch_size=3,          # batch size per device during training
    gradient_accumulation_steps=2,          # number of steps before performing a backward/update pass
    gradient_checkpointing=True,            # use gradient checkpointing to save memory
    optim="adamw_torch_fused",              # use fused adamw optimizer
    logging_steps=10,                       # log every 10 steps
    save_strategy="epoch",                  # save checkpoint every epoch
    learning_rate=2e-4,                     # learning rate, based on QLoRA paper
    bf16=True,                              # use bfloat16 precision -- bf16=True,   
    tf32=True,                              # use tf32 precision
    max_grad_norm=0.3,                      # max gradient norm based on QLoRA paper
    warmup_ratio=0.03,                      # warmup ratio based on QLoRA paper
    lr_scheduler_type="constant",           # use constant learning rate scheduler
    push_to_hub=False,                       # push model to hub
    report_to="tensorboard",                # report metrics to tensorboard
)




from trl import SFTTrainer

max_seq_length = 3072 # max sequence length for model and packing of the dataset

trainer = SFTTrainer(
    model=model,
    args=args,
    train_dataset=dataset,
    peft_config=peft_config,
    max_seq_length=max_seq_length,
    tokenizer=tokenizer,
    packing=True,
    dataset_kwargs={
        "add_special_tokens": False,  # We template with special tokens
        "append_concat_token": False, # No need to add additional separator token
    }
)




# start training, the model will be automatically saved to the hub and the output directory
trainer.train()

# save model
trainer.save_model()

# free the memory again
del model
del trainer
torch.cuda.empty_cache()
# Out:
# Generating train split: 100 examples [00:00, 17690.77 examples/s]
# Loading checkpoint shards: 100%|██████████| 2/2 [00:04<00:00,  2.41s/it]
# Generating train split: 3 examples [00:00, 54.04 examples/s]
# You're using a CodeLlamaTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# `use_cache=True` is incompatible with gradient checkpointing. Setting `use_cache=False`...
# /root/dev/genai/.venv/lib/python3.10/site-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# The input hidden states seems to be silently casted in float32, this might be related to the fact you have upcasted embedding or layer norm layers in float32. We will cast back the input in torch.bfloat16.
#     <div>
#
#       <progress value='3' max='3' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [3/3 00:36, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
# /root/dev/genai/.venv/lib/python3.10/site-packages/peft/utils/save_and_load.py:141: UserWarning: Setting `save_embedding_layers` to `True` as the embedding layer has been resized during finetuning.
#   warnings.warn(
# /root/dev/genai/.venv/lib/python3.10/site-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /root/dev/genai/.venv/lib/python3.10/site-packages/peft/utils/save_and_load.py:141: UserWarning: Setting `save_embedding_layers` to `True` as the embedding layer has been resized during finetuning.
#   warnings.warn(
# /root/dev/genai/.venv/lib/python3.10/site-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /root/dev/genai/.venv/lib/python3.10/site-packages/peft/utils/save_and_load.py:141: UserWarning: Setting `save_embedding_layers` to `True` as the embedding layer has been resized during finetuning.
#   warnings.warn(
# /root/dev/genai/.venv/lib/python3.10/site-packages/peft/utils/save_and_load.py:141: UserWarning: Setting `save_embedding_layers` to `True` as the embedding layer has been resized during finetuning.
#   warnings.warn(

# %% [markdown]
# Merge LoRA adapter in to the original model

# %%
#### COMMENT IN TO MERGE PEFT AND BASE MODEL ####
import torch
from peft import AutoPeftModelForCausalLM

output_dir = './models/codeLlama-7b-text-to-sql'

# Load PEFT model on CPU
model = AutoPeftModelForCausalLM.from_pretrained(
    output_dir,
    torch_dtype=torch.float16,
    low_cpu_mem_usage=True,
)
# Merge LoRA and base model and save
merged_model = model.merge_and_unload()
merged_model.save_pretrained(output_dir,safe_serialization=True, max_shard_size="2GB")
# Out:
# Loading checkpoint shards: 100%|██████████| 2/2 [00:03<00:00,  1.69s/it]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
